# %% [markdown]
# <a href="https://colab.research.google.com/github/H-T0rres/portfolio.github.io/blob/master/steamreqs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 req = pd.read_csv('output.csv')

# %%
requirments = pd.DataFrame(req)

# %%
requirments.head()
# Out:
#   Memory:                             Graphics Card:  \
# 0    6 GB                    NVIDIA GeForce GTX 980
# 1    8 GB                    NVIDIA GeForce GTX 960
# 2    8 GB   NVIDIA GeForce GTX 970  or Radeon RX 470
# 3    4 GB           Intel HD 4000  or Radeon HD 7870
# 4    4 GB                             Intel HD 4000
#
#                                        CPU: File Size:  \
# 0                       Intel Core i5-6600       30 GB
# 1                      Intel Core i5-2500K       70 GB
# 2           Intel Core i5-3570K  or FX-8310      70 GB
# 3                       Intel Core i3-3225       15 GB
# 4   Intel Core 2 Duo E8400  or Athlon 200GE      23 GB
#
#                       OS:                                 name
# 0              Windows 10  Hogwarts Legacy System Requirements
# 1       Windows 10 64-bit       God of War System Requirements
# 2       Windows 10 64-Bit   Cyberpunk 2077 System Requirements
# ...

# %%
requirments['name'] = requirments['name'].str.replace(' System Requirements', '')

requirments.head()
# Out:
#   Memory:                             Graphics Card:  \
# 0    6 GB                    NVIDIA GeForce GTX 980
# 1    8 GB                    NVIDIA GeForce GTX 960
# 2    8 GB   NVIDIA GeForce GTX 970  or Radeon RX 470
# 3    4 GB           Intel HD 4000  or Radeon HD 7870
# 4    4 GB                             Intel HD 4000
#
#                                        CPU: File Size:  \
# 0                       Intel Core i5-6600       30 GB
# 1                      Intel Core i5-2500K       70 GB
# 2           Intel Core i5-3570K  or FX-8310      70 GB
# 3                       Intel Core i3-3225       15 GB
# 4   Intel Core 2 Duo E8400  or Athlon 200GE      23 GB
#
#                       OS:             name
# 0              Windows 10  Hogwarts Legacy
# 1       Windows 10 64-bit       God of War
# 2       Windows 10 64-Bit   Cyberpunk 2077
# 3   Windows 7/8/10 64-bit         Fortnite
# 4        Windows 7 64-bit         Valorant
